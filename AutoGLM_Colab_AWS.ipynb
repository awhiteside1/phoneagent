# %% [markdown]
# # AutoGLM with AWS Genymotion Emulator
#
# ## ✅ Your Setup
#
# **AWS Emulator:**
# - Host: `54.90.119.139`
# - Port: `5555`
# - Type: Genymotion on AWS
#
# **Steps:**
# 1. Run installation (Steps 1-4)
# 2. Configure API (Step 5)
# 3. Connect to AWS emulator (Step 6)
# 4. Run AutoGLM commands!
#
# ---
#
# No tunneling needed - direct connection! 🚀

# %% [markdown]
# ## 📊 System Diagnostics

# %%
import sys, platform, os

print("=" * 60)
print("SYSTEM DIAGNOSTICS")
print("=" * 60)
print(f"\n📍 Python: {sys.version.split()[0]}")
print(f"📍 Platform: {platform.platform()}")
print(f"\n📂 Current Directory: {os.getcwd()}")

if os.path.exists('main.py'):
    print("✓ In AutoGLM directory")
else:
    print("⚠️ Not in AutoGLM directory yet")

print("\n" + "=" * 60)

# %% [markdown]
# ---
# # Step 1: Clone Repository

# %%
import os

print("🔄 Cloning AutoGLM...")

if os.path.exists('Open-AutoGLM'):
    print("⚠️ Removing existing directory...")
    # !rm -rf Open-AutoGLM

# !git clone https://github.com/zai-org/Open-AutoGLM.git
# %cd Open-AutoGLM

print(f"\n✅ Cloned to: {os.getcwd()}")

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
print("🔄 Installing Python dependencies...\n")

# !pip install -q -r requirements.txt

print("\n✅ Dependencies installed!")
# !pip list | grep -E 'anthropic|openai|requests'

# %% [markdown]
# ## Step 3: Install ADB

# %%
print("🔄 Installing ADB...")

# !apt-get update -qq
# !apt-get install -y -qq android-tools-adb android-tools-fastboot

print("\n✅ ADB installed!")
# !adb version

# %% [markdown]
# ## Step 4: Verify Installation

# %%
import sys, os, subprocess

print("=" * 60)
print("VERIFICATION")
print("=" * 60)

errors = []

print(f"\n✓ Python {sys.version.split()[0]}")

if os.path.exists('main.py'):
    print("✓ main.py found")
else:
    errors.append("main.py missing")

result = subprocess.run(['adb', 'version'], capture_output=True)
if result.returncode == 0:
    print("✓ ADB working")
else:
    errors.append("ADB failed")

print("\n" + "=" * 60)
if errors:
    print("❌ ERRORS:", errors)
else:
    print("✅ ALL CHECKS PASSED!")
print("=" * 60)

# %% [markdown]
# ---
# ## Step 5: Configure API

# %%
# 🔧 OpenAI Configuration (SOTA Model)

# Get your API key from: https://platform.openai.com/api-keys

BASE_URL = "https://api.openai.com/v1"
MODEL_NAME = "gpt-4o"  # GPT-4 Omni - Latest with vision
API_KEY = "sk-..."  # ⬅️ PASTE YOUR OPENAI API KEY HERE

print("=" * 60)
print("OPENAI CONFIGURATION")
print("=" * 60)
print(f"\n📡 URL: {BASE_URL}")
print(f"🤖 Model: {MODEL_NAME} (latest vision model)")
print(f"🔑 Key: {API_KEY[:10]}..." if len(API_KEY) > 10 else "⚠️ SET YOUR KEY!")

import os
os.environ['AUTOGLM_BASE_URL'] = BASE_URL
os.environ['AUTOGLM_MODEL'] = MODEL_NAME
os.environ['AUTOGLM_API_KEY'] = API_KEY

print("\n✅ Configuration saved")
print("=" * 60)

# %% [markdown]
# ---
# ## Step 6: Connect to AWS Emulator

# %%
# ✅ PRE-CONFIGURED for your AWS Genymotion emulator
AWS_HOST = "54.90.119.139"
ADB_PORT = "5555"

print(f"🔄 Connecting to AWS emulator at {AWS_HOST}:{ADB_PORT}...\n")

# !adb connect {AWS_HOST}:{ADB_PORT}

import time
time.sleep(2)

print("\n📱 Connected devices:")
# !adb devices -l

print("\n📋 Device info:")
# !adb shell getprop ro.product.model
# !adb shell getprop ro.build.version.release

print("\n🎉 AWS emulator connected!")

# %% [markdown]
# ---
# ## Step 7: Test Connection

# %%
print("📱 Current devices:")
# !adb devices -l

print("\n✅ Testing shell access:")
# !adb shell echo "Hello from AWS emulator!"

# %% [markdown]
# ---
# ## Step 8: Run AutoGLM

# %%
# Simple task example
TASK = "Open Chrome browser"

print(f"🤖 Running AutoGLM: {TASK}")
print("=" * 60)

# !python main.py \
  --base-url {BASE_URL} \
  --model {MODEL_NAME} \
  --apikey {API_KEY} \
  "{TASK}"

print("\n" + "=" * 60)
print("✅ Task completed!")

# %%
# Custom task - edit as needed
CUSTOM_TASK = """Open Chrome and search for 'AI automation',
scroll down, take a screenshot, and return to home screen"""

print(f"🤖 Running custom task...")
print(f"Task: {CUSTOM_TASK}")
print("=" * 60)

# !python main.py \
  --base-url {BASE_URL} \
  --model {MODEL_NAME} \
  --apikey {API_KEY} \
  "{CUSTOM_TASK}"

print("\n" + "=" * 60)
print("✅ Done!")

# %% [markdown]
# ---
# ## 🔧 Troubleshooting
#
# If connection is lost, run this:

# %%
print("🔧 Reconnecting to AWS emulator...\n")

# !adb disconnect
# !adb kill-server
# !adb start-server

import time
time.sleep(2)

AWS_HOST = "54.90.119.139"
ADB_PORT = "5555"

# !adb connect {AWS_HOST}:{ADB_PORT}

time.sleep(2)

print("\n📱 Devices:")
# !adb devices -l

# %% [markdown]
# ---
# ## 📚 Resources & Tips
#
# **AutoGLM:**
# - [GitHub Repo](https://github.com/zai-org/Open-AutoGLM)
# - [Documentation](https://github.com/zai-org/Open-AutoGLM/blob/main/README_en.md)
#
# **Tips:**
# 1. Keep your AWS emulator running
# 2. Check AWS security group allows port 5555
# 3. Test simple tasks before complex ones
# 4. Monitor AWS costs if running long sessions
#
# **AWS Security:**
# - Ensure port 5555 is only open to trusted IPs
# - Consider using VPN for production use
# - Monitor for unauthorized connections
